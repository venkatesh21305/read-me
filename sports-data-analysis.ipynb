# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the provided data
data = pd.DataFrame({
    "Class": [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12],
    "Year": [2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023],
    "Region": ["Ajmer", "Ajmer", "Bhubaneswar", "Bhubaneswar", "Chandigarh", "Chandigarh", "Delhi East", "Delhi East", "Pune", "Pune", "Guwahati", "Guwahati", "Panchkula", "Panchkula", "Bengaluru"],
    "Status": ["Regd", "Appd", "Regd", "Appd", "Regd", "Appd", "Regd", "Appd", "Regd", "Appd", "Regd", "Appd", "Regd", "Appd", "Regd"],
    "CTSA": [0, 0, 103, 101, 0, 0, 0, 0, 0, 0, 0, 0, 38, 38, 93],
    "GOVT": [4533, 4524, 7746, 7688, 13060, 13025, 100216, 99566, 1535, 1534, 20672, 20518, 357, 357, 70],
    "GOVT AIDED": [0, 0, 0, 0, 55, 55, 6420, 6393, 0, 0, 102, 101, 0, 0, 0],
    "INDEPENDENT": [86178, 85839, 69835, 69506, 89637, 89317, 64953, 64774, 22801, 22742, 20768, 20601, 118675, 118046, 12262],
    "JNV": [3741, 3730, 3823, 3809, 2549, 2537, 81, 81, 1673, 1662, 4536, 4481, 2231, 2225, 1901],
    "KV": [7736, 7725, 11465, 11431, 5861, 5844, 6669, 6661, 4859, 4849, 6071, 6047, 3615, 3607, 2363]
})

# Visualize the data
# For example, create box plots for different regions and their CTSA counts
plt.figure(figsize=(12, 6))
data.boxplot(column='CTSA', by='Region', grid=False, rot=45)
plt.title('CTSA Counts by Region')
plt.ylabel('CTSA Count')
plt.xlabel('Region')
plt.xticks(rotation=45)
plt.show()

# Create scatter plots to explore the relationship between GOVT attendance and GOVT AIDED attendance
plt.figure(figsize=(8, 6))
plt.scatter(data['GOVT'], data['GOVT AIDED'])
plt.title('Relationship between GOVT and GOVT AIDED Attendance')
plt.xlabel('GOVT Attendance')
plt.ylabel('GOVT AIDED Attendance')
plt.show()
